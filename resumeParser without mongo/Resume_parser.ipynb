# %%
import spacy
import json
from spacy.tokens import DocBin
from sklearn.model_selection import train_test_split
with open('/content/resumeparser.tds.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# Split the data into training and testing sets
training_data, testing_data = train_test_split(data, test_size=0.2, random_state=42)

#to create training spacy file
nlp = spacy.blank("en")
db = DocBin()
skipped = 0
total = 0

for item in training_data:
    if isinstance(item, dict):
        text = item.get('text', '')
        entities = item.get('entities', [])
    elif isinstance(item, tuple):
        text, entities = item
    else:
        continue

    doc = nlp.make_doc(text)
    valid_ents = []

    try:
        for start, end, label in entities:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            total += 1
            if (
                span is None
                or span.text.startswith(" ")
                or span.text.endswith(" ")
                or span.text != span.text.strip()
            ):
                ent_text = text[start:end]
                print(f"⚠  Skipping Entity : {text[0:30]}... {ent_text}")
                skipped += 1
            else:
                valid_ents.append(span)

        doc.ents = valid_ents
        db.add(doc)
    except Exception as ex:
        print("⚠ ", ex)
        skipped += 1

db.to_disk("training_data.spacy")


#to create testing spacy file
nlp = spacy.blank("en")
db = DocBin()
skipped = 0
total = 0

for item in testing_data:
    if isinstance(item, dict):
        text = item.get('text', '')
        entities = item.get('entities', [])
    elif isinstance(item, tuple):
        text, entities = item
    else:
        continue

    doc = nlp.make_doc(text)
    valid_ents = []

    try:
        for start, end, label in entities:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            total += 1
            if (
                span is None
                or span.text.startswith(" ")
                or span.text.endswith(" ")
                or span.text != span.text.strip()
            ):
                ent_text = text[start:end]
                print(f"⚠  Skipping Entity : {text[0:30]}... {ent_text}")
                skipped += 1
            else:
                valid_ents.append(span)

        doc.ents = valid_ents
        db.add(doc)
    except Exception as ex:
        print("⚠ ", ex)
        skipped += 1

db.to_disk("testing_data.spacy")

training_data_len=len(training_data)
print("✨ Results:")
print(f"Total Training Data : {training_data_len}")

print(f"Failed to Convert : {skipped} / {total} = {skipped/total*100} %")
# Out:
# ⚠  Skipping Entity : 		Present : Creative Logic Net... musthafampv786@gmail.com
# ⚠  Skipping Entity : Vaishali Kale
# Pune, Maharasht... C#
# ⚠  Skipping Entity : Vaishali Kale
# Pune, Maharasht... .net
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... Servlets
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... AWS
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... Servlets
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... Servlets
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... SPRING3.0
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... STRUTS2.0
# ⚠  Skipping Entity : Ravi Reddy
# SR. JAVA/J2EE DEVE... SpringSecurities
# ⚠  Skipping Entity : Rao
#
# 201-701-3757
#
# OBJECTI... Agile
# ⚠  Skipping Entity : RANDY ADAMS
# Sr. Java Develope... SERVELT
# ⚠  Skipping Entity : RANDY ADAMS
# Sr. Java Develope... JIRA
# ⚠  Skipping Entity : RANDY ADAMS
# Sr. Java Develope... J2EE
# ⚠  Skipping Entity : Surinder Kumar
# Ferozepur City... C++
# ⚠  Skipping Entity : 		Nitika Sharma
# 		Email:nitik... nitika92sharma@gmail.com
# ⚠  Skipping Entity : Chinna Subbarayudu M
#
# DOB: 0... EIB
# ... agarwal.jay7@gmail.com
# ⚠  Skipping Entity : 		RESUME
# 		RESUME
# 		DULAM SU... suprajateju.78@gmail.com
# ⚠  Skipping Entity : 		VIGNESH​ ​R
# 		vigneshramach... HTML
# ⚠  Skipping Entity : 		VIGNESH​ ​R
# 		vigneshramach... ​CSS
# ⚠  Skipping Entity : 		VIGNESH​ ​R
# 		vigneshramach... ​Javascript
# ⚠  Skipping Entity : 		VIGNESH​ ​R
# 		vigneshramach... ​Sketch
# ⚠  Skipping Entity : 		Gurpreet Singh
# 		Address:-D... gurpreet1489@gmail.com
# ⚠  Skipping Entity : 		Gurpreet Singh
# 		Address:-D... gurpreet9.singh@airtel.com
# ⚠  Skipping Entity : 		EDUCATIONAL QUALIFICATIONS
# ... Html5
# ⚠  Skipping Entity : 		EDUCATIONAL QUALIFICATIONS
# ... css3
# ⚠  Skipping Entity : 		EDUCATIONAL QUALIFICATIONS
# ... css2
# ⚠  Skipping Entity : 		EDUCATIONAL QUALIFICATIONS
# ... Jquery
# ⚠  Skipping Entity :                               ... C#
# ⚠  Skipping Entity :                               ... .Net
# ⚠  Skipping Entity : 		Y. Anusha
# 		Mobile: +91 934... C#
# ⚠  Skipping Entity : 		Y. Anusha
# 		Mobile: +91 934... .NET
# ⚠  Skipping Entity : 		Y. Anusha
# 		Mobile: +91 934... C#
# ⚠  Skipping Entity : 		Y. Anusha
# 		Mobile: +91 934... .NET
# ⚠  Skipping Entity : 		Y. Anusha
# 		Mobile: +91 934... C#
# ⚠  Skipping Entity : 		Y. Anusha
# 		Mobile: +91 934... NET
# ⚠  Skipping Entity : 		Microsoft Word - Priti_Gaikw... CSS3
# ⚠  Skipping Entity : 		Microsoft Word - Priti_Gaikw... Javascript
# ⚠  Skipping Entity : Nisha shinge
# Pune, Maharashtr... c#
# ⚠  Skipping Entity : Nisha shinge
# Pune, Maharashtr... sql
# ⚠  Skipping Entity : 		(
# 		Arpit Gupta
# 		Phone
# 	... DCL
# ⚠  Skipping Entity :
# Mounika
# Business Analyst   ... access
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		KAJAL SI... JAVA-
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		KAJAL SI... J2SE
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		KAJAL SI... -Kolkata
# ⚠  Skipping Entity : 		Resume_Sudha
# 		S U D H A P ... //www.linkedin.com/in/sudhaprasanthi-parimi-864016137/
# ⚠  Skipping Entity : 		RESUME
# 		Argharoop Saha
# 		... B.Com
# ⚠  Skipping Entity : Kanumuru Deepak Reddy
#
#
#
# 	... HTML5,CSS3
# ⚠  Skipping Entity : Kanumuru Deepak Reddy
#
#
#
# 	... Redux
# ⚠  Skipping Entity : Preeti Hans
# Front End Develop... //www.linkedin.com/in/preeti-hans-095a8a88
# ⚠  Skipping Entity : 		Curriculam-Vitae
# 		NAME : G... H-Block, House No. 11, Sec 12,
# 		Noida(U.P)
# ⚠  Skipping Entity : 		Curriculam-Vitae
# 		NAME : G... B.Com
# ⚠  Skipping Entity : 		Name:-Sanghavi Meet Bhupendr... -adimesan007@gmail.com
# ⚠  Skipping Entity : 		SHIVESH SRIVASTAVA
# 		Senior... beingshivesh@gmail.com
# ⚠  Skipping Entity : Puja Deshmane
# Pune, Maharasht... 72%
# ⚠  Skipping Entity : Puja Deshmane
# Pune, Maharasht... c#
# ⚠  Skipping Entity : Puja Deshmane
# Pune, Maharasht... asp.net
# ⚠  Skipping Entity : Puja Deshmane
# Pune, Maharasht... wpf
# ⚠  Skipping Entity : Puja Deshmane
# Pune, Maharasht... html
# ⚠  Skipping Entity : Saiteja
# +1(940)437-0150
# sait... Log4J
# ⚠  Skipping Entity : 		Mobile: 9733954229
# 		APURBA... BCA
# ⚠  Skipping Entity : 		Email ID:hirenprajapati003@g... hirenprajapati003@gmail.com
# ⚠  Skipping Entity : 		Email ID:hirenprajapati003@g... MVC
# ⚠  Skipping Entity : 		SATHISH KUMAR GATTU
# 		H-NO:... C#
# ⚠  Skipping Entity : 		SATHISH KUMAR GATTU
# 		H-NO:... .Net
# ⚠  Skipping Entity : 		SATHISH KUMAR GATTU
# 		H-NO:... C#
# ⚠  Skipping Entity : 		SATHISH KUMAR GATTU
# 		H-NO:... .NET
# ⚠  Skipping Entity : 		SAURABH TRIPATHI CK 49/103,B... 73%
# ⚠  Skipping Entity : 		SAURABH TRIPATHI CK 49/103,B... 70.3%
# ⚠  Skipping Entity : 		Rama Anjali.P
# 		Plot # 37, ... anjalisiims@gmail.com
# ⚠  Skipping Entity : 		Laxmi Narayan Nanda, MBA (HR... laxmi13029@gmail.com
# ⚠  Skipping Entity : 		Laxmi Narayan Nanda, MBA (HR... laxmi13029@gmail.com
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Sneha D.... T.Y.BBI
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Sneha D.... S.Y.BBI
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Sneha D.... F.Y.BBI
# ⚠  Skipping Entity : 		Bibek Mukherjee Mob: 9830082... bibek7588@gmail.com
# ⚠  Skipping Entity : 		Microsoft Word - SRAVANI TAL... JCL
# ⚠  Skipping Entity : 		Microsoft Word - SRAVANI TAL... DB2
# ⚠  Skipping Entity : 		Microsoft Word - SRAVANI TAL... JCL
# ⚠  Skipping Entity : 		Microsoft Word - SRAVANI TAL... DB2
# ⚠  Skipping Entity : 		RESUME
# 		SRINIDHI V.
# 		# 1... TallyErp9
# ⚠  Skipping Entity : 		RESUME
# 		SRINIDHI V.
# 		# 1... Saralpaybacktool
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		ANSARI M... C++
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		ANSARI M... C#
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		ANSARI M... Asp.net
# ⚠  Skipping Entity : 		Resume 2.docx.pages
# 		Vashi... -seth_2203@yahoo.com
# ⚠  Skipping Entity : Ram.
#
# Cell :  510-556-3630
# ... WebServices
# ⚠  Skipping Entity : 		Pavuluri Lakshmi Priyanka
# 	... priyankalakshmi21@gmail.com
# ⚠  Skipping Entity : 		Ashwin Malik
# 		Oracle DBA
# ... siddhantbele444@gmail.com
# ⚠  Skipping Entity : 		Ashwin Malik
# 		Oracle DBA
# ... 10g,11g(RAC)
# ⚠  Skipping Entity : 		Ashwin Malik
# 		Oracle DBA
# ... ,12c
# ⚠  Skipping Entity : 		Curriculum Vitae
# 		Curricul... B.Com
# ⚠  Skipping Entity : Name: Ravali P
#
#            ... Thirumaladevarahalli
# ⚠  Skipping Entity : Name: Ravali P
#
#            ... ,Parthihalli
# ⚠  Skipping Entity : Name: Ravali P
#
#            ... Kodigenahalli
# ⚠  Skipping Entity : Surinder Kumar
# Ferozepur City... C++
# ⚠  Skipping Entity :
# Priya								 	          (65... WebSphere
# ⚠  Skipping Entity : Arjun Reddy
# software develope... HTML5.CSS3
# ⚠  Skipping Entity : Arjun Reddy
# software develope... JS
# ⚠  Skipping Entity : KOUSALYA.S
#
# */***,******* **... C++
# ⚠  Skipping Entity : 		VIJENDRA KUSHWAH
# 		Mobile:9... vijendrakushwah171991@gmail.com
# ⚠  Skipping Entity : 		VIJENDRA KUSHWAH
# 		Mobile:9... S&FAS
# ⚠  Skipping Entity : 		Ho
# 		RESUME
# 		MOHAMMAD APS... mohammadapsar999@gmail.com
# ⚠  Skipping Entity : 		JOHN HAVEN
# ... b.com
# ⚠  Skipping Entity : ANIL KUMAR MADDUKURI
#
# SQ... B.Tech.
# ⚠  Skipping Entity : SUMMARY
#
# Full Stack Develope... Bootstrap
# ⚠  Skipping Entity : SUMMARY
#
# Full Stack Develope... JUNIT
# ⚠  Skipping Entity : Mahima Kad
# Batala, Punjab
# Wo... C++
# ⚠  Skipping Entity : 		Jayprakash Gudda Poojary
# 		... -poojaryjayprakash@gmail.com
# ⚠  Skipping Entity :                               ... Github
# ⚠  Skipping Entity :                               ... Ant
# ⚠  Skipping Entity :                               ... Java7
# ⚠  Skipping Entity :                               ... J2EE
# ⚠  Skipping Entity : 		SOBANA .B
# 		: 9003751214
# ... Malayalam
# ⚠  Skipping Entity : 		Firoz Ahmad
# 		Mobile: 98854... HTML-5
# ⚠  Skipping Entity : 		Firoz Ahmad
# 		Mobile: 98854... CSS
# ⚠  Skipping Entity : 		K. LALAIAH
# 		Contact: + 91 ... MBA
# ⚠  Skipping Entity : 		Prakash Kumar Jha Email: pra... prakash.jha86@gmail.com
# ⚠  Skipping Entity : 		CAREER OBJECTIVE
# 		Looking ... -suryawanshi.yashaswini@gmail.com
# ⚠  Skipping Entity : 		CAREER OBJECTIVE
# 		Looking ... Gandharva2016
# ⚠  Skipping Entity : 		RESUME
# 		RESUME
# 		Name: SU... JSP
# ⚠  Skipping Entity : 		RESUME
# 		RESUME
# 		Name: SU... SQL
# ⚠  Skipping Entity : 		Name:- Vasudha Jawaharlal Ku... C#
# ⚠  Skipping Entity : 		Name:- Vasudha Jawaharlal Ku... .NET
# ⚠  Skipping Entity : 		CURRICULAM VITAE
# 		RESUME
# ... C#
# ⚠  Skipping Entity : 		CURRICULAM VITAE
# 		RESUME
# ... .NET
# ⚠  Skipping Entity : 		CURRICULAM VITAE
# 		RESUME
# ... C#
# ⚠  Skipping Entity : 		CURRICULAM VITAE
# 		RESUME
# ... .NET
# ⚠  Skipping Entity : 		SOUNDARYAPRABHA. M (
# ... S/o .A. Mohan
# 		4/112A,Mullai Street,Swamysonaiyanagar,
# 		Madurai
# ⚠  Skipping Entity : 		Pankaj Baviskar
# 		CURRICULU... C#
# ⚠  Skipping Entity : 		Pankaj Baviskar
# 		CURRICULU... .net
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Syed Irf... B.COM
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Syed Irf... Drawing
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Position... Finacle
# 		· M.S.Office
# ⚠  Skipping Entity : 		SAP BASIS HANA CONUSLTANT
# 	... narenraju51@gmail.com
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		RESUME
# ... kapse.rajesh87@gmail.com
# ⚠  Skipping Entity :
# Priya Sharma
#
#  manjunath@n... Priya Sharma
#
#  manjunath
# ⚠  Skipping Entity :
# Priya Sharma
#
#  manjunath@n... @nichesoftsolutions.com
# ⚠  Skipping Entity :
# PANKAJ P
# SR BUSINESS SYSTEM... C#
# ⚠  Skipping Entity :
# PANKAJ P
# SR BUSINESS SYSTEM... .NET
# ⚠  Skipping Entity :
# PANKAJ P
# SR BUSINESS SYSTEM... C#
# ⚠  Skipping Entity :
# PANKAJ P
# SR BUSINESS SYSTEM... .NET
# ⚠  Skipping Entity :
# Rashmithareddy
# Email:... Hyd
# ⚠  Skipping Entity : Nilkanth Jagtap
# Pune, Maharas... BE
# ⚠  Skipping Entity : 		RESUME
# 		Name: Amit Saha
# 	... amits048@gmail.com
# ⚠  Skipping Entity : 		RAVI KANCHAN SHARMA
# 		Curri... debasishhira1990@gmail.com
# ⚠  Skipping Entity : Pranay
#     Email: pranaypjav... DB2
# ⚠  Skipping Entity : 		CURRICULUM VITTAE
# 		Zubair ... NETFLOW
# ⚠  Skipping Entity : 		RESUME
# 		RESUME
# 		GAUTAM S... gautamsrinivas9@gmail.com
# ⚠  Skipping Entity : 		Name
# ... Hibernate4
# ⚠  Skipping Entity : 		Name
# ... MySQL
# ⚠  Skipping Entity : 		Name
# ... Javascript
# ⚠  Skipping Entity : Vaishali Kale
# Pune, Maharasht... C#
# ⚠  Skipping Entity : Vaishali Kale
# Pune, Maharasht... .net
# ⚠  Skipping Entity : 		Milan R
# 		BHAVANASUPRAJA
# 	... C#
# ⚠  Skipping Entity : 		Milan R
# 		BHAVANASUPRAJA
# 	... .Net
# ⚠  Skipping Entity : 		Jasmeet Matharu - Recruitmen... jasmeetmatharu19@gmail.com
# ⚠  Skipping Entity : 		SURENDAR.B
# 		No:110,I-Block... surensurendar18@gmail.com
# ⚠  Skipping Entity : 		SURENDAR.B
# 		No:110,I-Block... BSC
# ⚠  Skipping Entity : Upasna Upadhayay
# Kota, Rajast... C++
# ⚠  Skipping Entity : Upasna Upadhayay
# Kota, Rajast... C#
# ⚠  Skipping Entity : Upasna Upadhayay
# Kota, Rajast... HTML
# ⚠  Skipping Entity : PRIYANKA                      ... AWS
# ⚠  Skipping Entity : 		SIRISHAKUMAR
# 		E-Mail:kumar... kumarsirisha@ymail.com
# ⚠  Skipping Entity : 		SIRISHAKUMAR
# 		E-Mail:kumar... PrivilegeBanker
# ⚠  Skipping Entity : 		SIRISHAKUMAR
# 		E-Mail:kumar... Projecton“Comparisonofthejobsatisfactionlevelsofemployeesbetweenpublicandprivatesectorbanks”
# ⚠  Skipping Entity : 		Curriculum Vitae
# 		Shaik Ab... C
# ⚠  Skipping Entity : 		Curriculum Vitae
# 		Shaik Ab... B
# ⚠  Skipping Entity : 		Contact Details:
# 		Dr. Ayan... drayan.kundu5@gmail.com
# ⚠  Skipping Entity : 		Curriculum vita
# 		RahulV.S... rahulslk84@gmail.com
# ⚠  Skipping Entity : 		Curriculum vita
# 		RahulV.S... Tellly
# ⚠  Skipping Entity : Shirish Nakhate
# SQL developer... -C
# ⚠  Skipping Entity : Mohammed Huzaifa A
# Bangalore,... Java
# ⚠  Skipping Entity : Mohammed Huzaifa A
# Bangalore,... c#
# ⚠  Skipping Entity : Mohammed Huzaifa A
# Bangalore,... mysql
# ⚠  Skipping Entity : Hyma Gumpu
#    danny@stackitpr... Hyma Gumpu
#    danny
# ⚠  Skipping Entity : Hyma Gumpu
#    danny@stackitpr... stackitprofessionals.com
# ⚠  Skipping Entity : 		MANIMARAN.M
# 		132, MAINROAD... manisharma305@gmail.com
# ⚠  Skipping Entity : 		RESUME
# 		Shailaja Rajput
# 	... shailajarajput121@gmail.com
# ⚠  Skipping Entity : 		Joseph Lurdu Antoine, A.
# 		... antojoe11@gmail.com
# ⚠  Skipping Entity : 		Kalpana K,Mobile: +
# 		Call ... priyankachougule7890@mail.com
# ⚠  Skipping Entity :
# SUSOVAN  BAG
# Seeking  ... C++
# ⚠  Skipping Entity :
# SUSOVAN  BAG
# Seeking  ... Java
# ⚠  Skipping Entity :
# SUSOVAN  BAG
# Seeking  ... HOTEL  MANAGEMENT  SYSTEM
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		HARI MAL... C#
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		HARI MAL... C#
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		HARI MAL... ASP.net
# ⚠  Skipping Entity : 		Contact details
# 		Permanent... C++
# ⚠  Skipping Entity : 		Contact details
# 		Permanent... HDL
# ⚠  Skipping Entity : 		siddharth garg
# 		Siddharth ... B.E
# ⚠  Skipping Entity : 		karishma bellani
# 		KARISHMA... kari_bellani10694@yahoo.com
# ⚠  Skipping Entity : 		RESUME
# 		DILEEP KOTANA
# 		E... -vspcdvm@gmail.com
# ⚠  Skipping Entity :                               ... Appium
# ⚠  Skipping Entity :                               ... Selenium
# ⚠  Skipping Entity : Varsha Jagtap
# Pune, Maharasht... Java
# ⚠  Skipping Entity : 		RESUME
# 		RESUME
# 		Gowri Sa... Chennai-600081
# ⚠  Skipping Entity : 		RESUME
# 		Prashant Surendra ... B.Sc
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		BHAVNEES... nishubhatia06@gmail.com
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		BHAVNEES... Windows7
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		BHAVNEES... Windows8
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		BHAVNEES... C++
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		BHAVNEES... Java
# ⚠  Skipping Entity : Ram.
#
# Cell :  510-556-3630
# ... WebServices
# ⚠  Skipping Entity : 		Curriculum Vitae
# 		Curricul... GNIIT
# ⚠  Skipping Entity : 		Curriculum Vitae
# 		Curricul... VC#
# ⚠  Skipping Entity : 		Curriculum Vitae
# 		Curricul... C++
# ⚠  Skipping Entity : 		RESUME
# 		RESUME
# 		Mayur Ma... -mayur858559@yahoo.co.in
# ⚠  Skipping Entity : 		1
# 		NAYANA K M
# 		CAREER OB... :Nayanakm23@gmail.com
# ⚠  Skipping Entity :
#
# Name: Harshitha           ... harshithac511@gmail.com
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Rupa Hal... C++
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		Rupa Hal... VB.Net
# ⚠  Skipping Entity : 		RESUME
# 		M. BALAMBIGAI No:2... balambigai_here@yahoo.com
# ⚠  Skipping Entity : Nikhil
# Sr. J2EE/AWS Develope... nikhil.akula06@gmail.com
# ⚠  Skipping Entity : Nikhil
# Sr. J2EE/AWS Develope... Eclipse
# ⚠  Skipping Entity : 		Phone No:
# ... C++
# ⚠  Skipping Entity : 		Phone No:
# ... Java
# ⚠  Skipping Entity : 		Bibek Mukherjee Mob: 9830082... bibek7588@gmail.com
# ⚠  Skipping Entity : 		APPALANAIDU POTHALA
# 		Mobil... 55%
# ⚠  Skipping Entity : 		CURRICULUM VITAE
# 		ANIL RAM... nimmaanil56@gmail.com
# ⚠  Skipping Entity : Hari Babu
# Email:hariguraka@gm... hariguraka@gmail.com
# ⚠  Skipping Entity : 		Guardian:
# 		Mr. Basil Baby ... chinjujava@gmail.com
# ⚠  Skipping Entity : PRAVEEN T
# Senior ... AWS
# ⚠  Skipping Entity : 		Chaitanya Khatri Contact Num... ckhatri8@gmail.com
# ⚠  Skipping Entity : 		CURRICULUM-VITAE
# 		E-mail-s... Spring
# 		Database
# ⚠  Skipping Entity : 		RESUME
# 		Name: Prasanna Ven... Hindi
# ⚠  Skipping Entity : nikhil sharma
# Ahmedabad, Guja... c++
# ⚠  Skipping Entity : nikhil sharma
# Ahmedabad, Guja... //s.nikhil01234@gmail.com
# ⚠  Skipping Entity : 		Nirav Doshi
# 		Career object... B.M.S.
# ⚠  Skipping Entity :
# Mounika P
# Front End Develop... knout.js
# ⚠  Skipping Entity : Name: Mohid
# Phone: 857-228-49... Linux
# ⚠  Skipping Entity : 		RESUME
# 		SREENATH PC
# 		Nan... srinathpc47@gmail.com
# ✨ Results:
# Total Training Data : 539
# Failed to Convert : 50 / 5413 = 0.9237021984112322 %

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2023-10-16 12:58:18.427105: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy debug data config.cfg  --paths.train ./training_data.spacy --paths.dev ./testing_data.spacy
# Out:
# 2023-10-16 12:59:42.546118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# ============================ Data file validation ============================
# ✔ Pipeline can be initialized with data
# ✔ Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 539 training docs
# 135 evaluation docs
# ⚠ 10 training examples also in evaluation data
# ⚠ Low number of examples to train a new pipeline (539)
#
# ============================== Vocab & Vectors ==============================
# ℹ 600787 total word(s) in the data (31106 unique)
# ℹ No word vectors present in the package
#
# ========================== Named Entity Recognition ==========================
# ℹ 26 label(s)
# 0 missing value(s) (tokens with '-' label)
# ⚠ Low number of examples for label 'GPA/PERCENTAGE' (4)
# ⚠ Low number of examples for label 'TECHNOLOGICS' (22)
# ⚠ Low number of examples for label 'WORK EXPERIANCE' (5)
# ⚠ Low number of examples for label 'LINKEDIN/GITHUB' (3)
# ⚠ Low number of examples for label 'INTERNSHIP' (10)
# ⚠ Low number of examples for label 'UNIVERSITY/COLLEGE' (47)
# ⚠ Low number of examples for label 'TECHNOLOGIES ' (2)
# ⚠ Low number of examples for label 'EXTRA CIRCULAR' (5)
# ⚠ Low number of examples for label 'ACHEIVEMENTS' (2)
# ✔ Examples without occurrences available for all labels
# ✔ No entities consisting of or starting/ending with whitespace
# ✔ No entities crossing sentence boundaries
#
# ================================== Summary ==================================
# ✔ 5 checks passed
# ⚠ 11 warnings

# %%
# !python -m spacy train config.cfg  --output ./output_model --paths.train ./training_data.spacy --paths.dev ./testing_data.spacy
# Out:
# 2023-10-16 13:01:07.252696: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Created output directory: output_model
# ℹ Saving to output directory: output_model
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00    127.23    0.00    0.00    0.00    0.00
#   0     200       3288.21  32123.79   22.34   34.19   16.60    0.22
#   0     400       7388.94  17286.36    9.00   45.04    5.00    0.09
#   1     600      12158.21  19072.15   19.80   36.70   13.56    0.20
#   1     800      17485.43  15317.48   16.98   46.46   10.39    0.17
#   1    1000      48324.28  14442.64   32.18   36.92   28.51    0.32
#   2    1200      21694.33  14982.02   17.92   44.98   11.19    0.18
#   2    1400      13669.83  13164.21   22.64   26.14   19.97    0.23
#   2    1600       9884.78  12496.72   30.47   41.78   23.98    0.30
#   3    1800       6687.27  14280.75   35.29   35.41   35.17    0.35
#   3    2000      21081.07  13254.72   29.38   46.02   21.57    0.29
#   4    2200      13843.07  11699.31   28.45   37.57   22.90    0.28
#   4    2400      15851.72  14366.99   23.00   41.78   15.87    0.23
#   4    2600      11850.58  10780.55   33.79   42.45   28.06    0.34
#   5    2800       7703.97  12675.10   30.55   42.62   23.81    0.31
#   5    3000       7077.42  12293.52   32.69   41.96   26.78    0.33
#   5    3200       9590.46  11959.79   18.99   43.32   12.16    0.19
#   6    3400       5829.14  11295.06   36.32   39.69   33.47    0.36
#   6    3600      15737.38  12229.30   25.75   39.44   19.11    0.26
#   7    3800       7685.43  12507.00   28.83   33.72   25.17    0.29
#   7    4000      13217.37  11654.68   23.60   34.64   17.90    0.24
#   7    4200       9883.00  12077.89   29.85   39.32   24.05    0.30
#   8    4400       9747.39  12160.29   27.01   43.16   19.65    0.27
#   8    4600       6684.28  11256.61   34.62   40.86   30.04    0.35
#   8    4800       5393.51  11489.56   28.87   42.30   21.91    0.29
#   9    5000       5303.91  11304.27   28.04   44.99   20.36    0.28
# ✔ Saved pipeline to output directory
# output_model/model-last

# %%
import spacy

nlp = spacy.load("./output_model/model-best")

text = """
 SASIDHAR THOTA
22 Giralda Close, E16 3SZ
+44 7471004624 sasi.thota7777@gmail.com LinkedIn
PERSONAL PROFILE
An enthusiastic and confident Software Engineer with a demonstrated history of working and experience in IT for
around 2 years. Skilled in Python, TypeScript, HTML, and CSS languages and Django, Angular and .NET frameworks
with experience in web development. Currently looking for an opportunity where I can grow professionally and aid in
the growth of the organization.
EDUCATION
2021 – 2022 University of Leicester School of Business, Leicester, United Kingdom.
International Management MSc - Merit
2014 – 2018 Vignan's Lara Institute of Technology and Science, Guntur, Andhra Pradesh, India.
Department of Electronics & Communication Engineering - First Class
TECHNICAL SKILLS
• Languages: Python, TypeScript, C#
• Web Technologies: HTML5, CSS3, Material UI, Kendo UI, Bootstrap
• Frameworks and Library: Django, Angular, .NET
• Webservices: Postman
• Version Control: GIT, Team Foundation Server (TFS)
• Database: MSSQL, Oracle
• Methodologies: Agile, Waterfall
ACADEMIC PROJECTS
• Industry 4.0: The Challenges and Benefits of Smart and Lean Manufacturing Adaptation for Manufacturing
SME’s.
RELEVANT WORK EXPERIENCE
September 2018 – October 2020 Tata Consultancy Services, Mumbai, Maharashtra, India.
Role: Full Stack Developer
Responsibilities:
• Analysing stories, writing code, implementing functional testing, contributing to release and iteration
planning.
• Expertise in building web applications ideally using Python in Django MVT Framework, Type Script in Angular
Framework, HTML, CSS, and Bootstrap.
• Experience in building front end UI using material UI and kendo UI frameworks.
• Implemented backend scripts through .NET and Python.
• Proficiency in creating SQL procedures in MsSQL and Oracle.
• Extensive experience in both mobile and desktop web application.
• Version Management using Team Foundation Server (TFS) and GIT.
• Performed system and integration testing with sample and live data.
• Maintain quality and ensure responsiveness of applications.
• Strong troubleshooting skills.
• Participated in project planning and/or provide accurate estimates on projects/tasks and supported during
production deployments.
• A profound experience to work in large, collaborative teams to achieve organizational goals.
• Learning new frameworks and providing knowledge transfer sessions to guide fellow teammates.
CERTIFICATIONS
• Python (Basic) Certified from HackerRank in May 2022.
• Angular (Basic) Certified from HackerRank in May 2022.
• SQL (Basic) Certified from HackerRank in May 2022.
• Problem Solving (Basic) Certified from HackerRank in Sep 2020.
ACHEIVEMENTS & AWARDS
• Tata Consultancy Services, Mumbai Maharashtra, India.
1. September 2020 Star Team Award: Excellence in Customer Delivery for outstanding performance.
2. Aug 2020 Star of The Month Award: Awarded for coherent deliverables in the developing application
with no defects and before time. Additionally creating concept application based on new technology and
integrating the same with application for enhanced features and performance.
3. May 2020 Ally of the Business Award: Awarded for untiring support and unwavering dedication, in
making virtual infrastructure functional as it enabled the smooth transition of systems and processes in a
time of crisis. The achievement is noted one of the highest in corporate ranks as it enabled business
continuity in a critical phase.
4. Dec 2019 Best Team Award: Exhibit Teamwork to achieve a major team goal and provide consistent
quality of services.
5. Jun 2019 Star of The Month Award: Awarded for coherent deliverables in the developing application
with no defects and before time. Accord achievement for a fresh graduate in the shortest possible time.
6. May 2019 On the Spot Award: Team-building activity conducted for own/other teams, displayed
creativity at work, and Active role in supporting organizational initiative
DECLARATION
I hereby declare that the above information provided is true to the best of my knowledge.
Sasidhar Thota
"""

doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# sasi.thota7777@gmail.com EMAIL
# TypeScript SKILLS
# HTML SKILLS
# Django SKILLS
# Angular SKILLS
# Python SKILLS
# TypeScript SKILLS
# C# SKILLS
# HTML5 TECHNOLOGIES
# Bootstrap SKILLS
# Django TECHNOLOGIES
# Angular SKILLS
# .NET SKILLS
# MSSQL SKILLS
# Oracle SKILLS
# Agile TECHNOLOGIES
# Full Stack Developer
# Responsibilities:
# • Analysing stories, writing code JOB ROLE
# Type Script SKILLS
# HTML SKILLS
# CSS SKILLS
# Strong troubleshooting skills. SKILLS
# Python SKILLS
# Angular SKILLS
# SQL SKILLS
# Problem Solving SKILLS
# September 2020 Star Team Award: Excellence in Customer Delivery for outstanding performance. WORK EXPERIENCE
